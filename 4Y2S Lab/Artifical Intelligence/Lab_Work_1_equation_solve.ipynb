# %% [markdown]
# # Import Necessary Library

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
import tensorflow as tf
from keras.models import Sequential
import numpy as np

# %% [markdown]
# # Generate Dataset

# %%
# Generate the training data
np.random.seed(0)
x = np.random.uniform(-10, 10, (1000, 1))
# x = np.random.random(1000)
y = 3 * x**3 + 7 * x**2 - 12 * x + 2

# %%
print(x[:10])
# Out:
# [[ 0.97627008]
#  [ 4.30378733]
#  [ 2.05526752]
#  [ 0.89766366]
#  [-1.52690401]
#  [ 2.91788226]
#  [-1.24825577]
#  [ 7.83546002]
#  [ 9.27325521]
#  [-2.33116962]]

# %%
print(x[:10])
# Out:
# [[ 0.97627008]
#  [ 4.30378733]
#  [ 2.05526752]
#  [ 0.89766366]
#  [-1.52690401]
#  [ 2.91788226]
#  [-1.24825577]
#  [ 7.83546002]
#  [ 9.27325521]
#  [-2.33116962]]

# %% [markdown]
# # Design Network Layers

# %%
# Define the model architecture
model = Sequential([
    Dense(64, input_shape=((1,)), activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
# Train the model
model.fit(x, y, batch_size=32, epochs=800)
# Out:
# Epoch 1/800
# 32/32 [==============================] - 1s 2ms/step - loss: 1301520.3750 - accuracy: 0.0000e+00
# Epoch 2/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1293467.5000 - accuracy: 0.0000e+00
# Epoch 3/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1280417.2500 - accuracy: 0.0000e+00
# Epoch 4/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1254950.8750 - accuracy: 0.0000e+00
# Epoch 5/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1214013.2500 - accuracy: 0.0000e+00
# Epoch 6/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1151803.7500 - accuracy: 0.0000e+00
# Epoch 7/800
# 32/32 [==============================] - 0s 2ms/step - loss: 1066899.3750 - accuracy: 0.0000e+00
# Epoch 8/800
# 32/32 [==============================] - 0s 2ms/step - loss: 958849.0625 - accuracy: 0.0000e+00
# Epoch 9/800
# ...

# %% [markdown]
# # Output of the equation

# %%
model.predict([-3,-2,-1,0,1,2])

# %%
xin = np.array([0,100,1,-2,2,3,-3])
yout= model.predict(xin)

# %%
yout

# %%
def output(x):
  p = 3 * x**3 + 7 * x**2 - 12 * x + 2
  return p
output(-3)

# %%
# print(xin*xmax)
for i in range(0,len(xin)):
  print("input=",xin[i],end="   ")
  print("predicted_output=",format(yout[i][0], ".2f"),"  original_output=",format(output(xin[i]),".2f"))
